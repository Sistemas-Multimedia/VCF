# %% [markdown]
# ## PNG Encoding

# %%
from IPython.display import Image, display

# %%
#!pip install -r ../requirements.txt

# %% [markdown]
# ### Help about basic functionality

# %%
# !python ../src/PNG.py -h

# %% [markdown]
# ### Help about how to encode

# %%
# !python ../src/PNG.py encode -h
# Out:
# usage: PNG.py encode [-h] [-i INPUT] [-o OUTPUT]
#
# options:
#   -h, --help           show this help message and exit
#   -i, --input INPUT    Input image (default:
#                        http://www.hpca.ual.es/~vruiz/images/lena.png)
#   -o, --output OUTPUT  Output image (default: /tmp/encoded)

# %% [markdown]
# ### Encode default (remote) image

# %%
# !python ../src/PNG.py -g encode
# Out:
# main Namespace(debug=True, subparser_name='encode', input='http://www.hpca.ual.es/~vruiz/images/lena.png', output='/tmp/encoded', func=<function encode at 0x7ff898758540>)
# (INFO) main main 18: input = http://www.hpca.ual.es/~vruiz/images/lena.png
# (INFO) main main 19: output = /tmp/encoded
# (DEBUG) PNG __init__ 28: trace
# (DEBUG) entropy_image_coding __init__ 26: trace args=Namespace(debug=True, subparser_name='encode', input='http://www.hpca.ual.es/~vruiz/images/lena.png', output='/tmp/encoded', func=<function encode at 0x7ff898758540>)
# (DEBUG) entropy_image_coding __init__ 32: self.encoding = True
# (DEBUG) entropy_image_coding encode 147: trace
# (DEBUG) entropy_image_coding encode_read 111: trace
# (DEBUG) entropy_image_coding encode_read_fn 82: trace fn=http://www.hpca.ual.es/~vruiz/images/lena.png
# (DEBUG) PngImagePlugin call 203: STREAM b'IHDR' 16 13
# (DEBUG) PngImagePlugin call 203: STREAM b'tEXt' 41 335
# (DEBUG) PngImagePlugin call 203: STREAM b'tEXt' 388 47
# (DEBUG) PngImagePlugin call 203: STREAM b'tIME' 447 7
# (DEBUG) PngImagePlugin _open 783: b'tIME' 447 7 (unknown)
# (DEBUG) PngImagePlugin call 203: STREAM b'pHYs' 466 9
# (DEBUG) PngImagePlugin call 203: STREAM b'IDAT' 487 512170
# (DEBUG) entropy_image_coding encode_read_fn 96: Read 512673 bytes from http://www.hpca.ual.es/~vruiz/images/lena.png with shape (512, 512, 3) and type=uint8
# (DEBUG) entropy_image_coding decode_write_fn 168: trace img=[[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 83  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]
# (DEBUG) entropy_image_coding decode_write_fn 169: trace fn=/tmp/original.png
# (DEBUG) Image init 388: Importing AvifImagePlugin
# (DEBUG) Image init 388: Importing BlpImagePlugin
# (DEBUG) Image init 388: Importing BmpImagePlugin
# (DEBUG) Image init 388: Importing BufrStubImagePlugin
# (DEBUG) Image init 388: Importing CurImagePlugin
# (DEBUG) Image init 388: Importing DcxImagePlugin
# (DEBUG) Image init 388: Importing DdsImagePlugin
# (DEBUG) Image init 388: Importing EpsImagePlugin
# (DEBUG) Image init 388: Importing FitsImagePlugin
# (DEBUG) Image init 388: Importing FliImagePlugin
# (DEBUG) Image init 388: Importing FpxImagePlugin
# (DEBUG) Image init 391: Image: failed to import FpxImagePlugin: No module named 'olefile'
# (DEBUG) Image init 388: Importing FtexImagePlugin
# (DEBUG) Image init 388: Importing GbrImagePlugin
# (DEBUG) Image init 388: Importing GifImagePlugin
# (DEBUG) Image init 388: Importing GribStubImagePlugin
# (DEBUG) Image init 388: Importing Hdf5StubImagePlugin
# (DEBUG) Image init 388: Importing IcnsImagePlugin
# (DEBUG) Image init 388: Importing IcoImagePlugin
# (DEBUG) Image init 388: Importing ImImagePlugin
# (DEBUG) Image init 388: Importing ImtImagePlugin
# (DEBUG) Image init 388: Importing IptcImagePlugin
# (DEBUG) Image init 388: Importing JpegImagePlugin
# (DEBUG) Image init 388: Importing Jpeg2KImagePlugin
# (DEBUG) Image init 388: Importing McIdasImagePlugin
# (DEBUG) Image init 388: Importing MicImagePlugin
# (DEBUG) Image init 391: Image: failed to import MicImagePlugin: No module named 'olefile'
# (DEBUG) Image init 388: Importing MpegImagePlugin
# (DEBUG) Image init 388: Importing MpoImagePlugin
# (DEBUG) Image init 388: Importing MspImagePlugin
# (DEBUG) Image init 388: Importing PalmImagePlugin
# (DEBUG) Image init 388: Importing PcdImagePlugin
# (DEBUG) Image init 388: Importing PcxImagePlugin
# (DEBUG) Image init 388: Importing PdfImagePlugin
# (DEBUG) Image init 388: Importing PixarImagePlugin
# (DEBUG) Image init 388: Importing PngImagePlugin
# (DEBUG) Image init 388: Importing PpmImagePlugin
# (DEBUG) Image init 388: Importing PsdImagePlugin
# (DEBUG) Image init 388: Importing QoiImagePlugin
# (DEBUG) Image init 388: Importing SgiImagePlugin
# (DEBUG) Image init 388: Importing SpiderImagePlugin
# (DEBUG) Image init 388: Importing SunImagePlugin
# (DEBUG) Image init 388: Importing TgaImagePlugin
# (DEBUG) Image init 388: Importing TiffImagePlugin
# (DEBUG) Image init 388: Importing WebPImagePlugin
# (DEBUG) Image init 388: Importing WmfImagePlugin
# (DEBUG) Image init 388: Importing XbmImagePlugin
# (DEBUG) Image init 388: Importing XpmImagePlugin
# (DEBUG) Image init 388: Importing XVThumbImagePlugin
# (DEBUG) entropy_image_coding decode_write_fn 177: Written 479828 bytes in /tmp/original.png with shape (512, 512, 3) and type uint8
# (DEBUG) entropy_image_coding compress 74: trace img=[[[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  [[226 137 125]
#   [226 137 125]
#   [223 137 133]
#   ...
#   [230 148 122]
#   [221 130 110]
#   [200  99  90]]
#
#  ...
#
#  [[ 84  18  60]
#   [ 84  18  60]
#   [ 92  27  58]
#   ...
#   [173  73  84]
#   [172  68  76]
#   [177  62  79]]
#
#  [[ 82  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]
#
#  [[ 83  22  57]
#   [ 82  22  57]
#   [ 96  32  62]
#   ...
#   [179  70  79]
#   [181  71  81]
#   [185  74  81]]]
# (DEBUG) PNG compress_fn 33: trace
# (DEBUG) PNG compress_fn 36: Input to io.BytesIO() witn range [1, 255]
# /home/vruiz/repos/VCF/notebooks/../src/PNG.py:42: FutureWarning: The plugin infrastructure in `skimage.io` and the parameter `plugin` are deprecated since version 0.25 and will be removed in 0.27 (or later). To avoid this warning, please do not use the parameter `plugin`. Instead, use `imageio` or other I/O packages directly. See also `imsave`.
#   skimage_io.imsave(fname=compressed_img, arr=img, plugin="pil", check_contrast=False)
# (DEBUG) entropy_image_coding encode_write 129: trace compressed_img=<_io.BytesIO object at 0x7ff895d10ae0>
# (DEBUG) entropy_image_coding encode_write_fn 116: trace codestream=<_io.BytesIO object at 0x7ff895d10ae0>
# (DEBUG) entropy_image_coding encode_write_fn 117: trace fn_without_extension=/tmp/encoded
# (INFO) entropy_image_coding encode_write_fn 125: Written 479828 bytes in /tmp/encoded.png
# (DEBUG) entropy_image_coding bye 37: trace
# (INFO) entropy_image_coding bye 50: Total 512673 bytes read
# (INFO) entropy_image_coding bye 51: Total 479828 bytes written
# (INFO) entropy_image_coding bye 56: Output bit-rate = 14.6431884765625 bits/pixel

# %% [markdown]
# ### Help to decode

# %%
# !python ../src/PNG.py decode -h

# %% [markdown]
# ### Decode default image

# %%
# !python ../src/PNG.py -g decode

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Encoding and decoding a local images

# %%
# !wget http://www.hpca.ual.es/~vruiz/images/Homer.png -O /tmp/Homer.png

# %%
# !python ../src/PNG.py encode -i /tmp/Homer.png -o /tmp/Homer_copy.png

# %%
# !python ../src/PNG.py decode -o /tmp/Homer_dec.png -i /tmp/Homer_copy.png

# %%
display(Image(filename="/tmp/Homer.png"))

# %% [markdown]
# ### Debugging without a filter

# %%
# !python ../src/PNG.py -g encode

# %%
# %%bash
# python ../src/PNG.py -g encode 2>&1 | grep trace
