# %% [markdown]
# ## No filtering
# Bypassing the filtering stage.

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %% [markdown]
# ### Help

# %%
# !python ../src/no_filter.py -h

# %%
# !python ../src/no_filter.py encode -h

# %% [markdown]
# ### "Encoding"

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_filter.py encode

# %% [markdown]
# ### "Decoding"

# %%
# %%bash
# python ../src/no_filter.py decode -h

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/no_filter.py decode

# %%
display(Image(filename="/tmp/decoded.png"))

# %%
# %%bash
# python ../src/RDE.py

# %% [markdown]
# ### Choosing the entropy codec

# %% [markdown]
# #### PNG

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_filter.py encode -c PNG

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/no_filter.py decode -c PNG

# %%
display(Image(filename="/tmp/decoded.png"))

# %%
# %%bash
# python ../src/RDE.py

# %% [markdown]
# #### CBAAC

# %%
# %%bash
# rm /tmp/encoded*
# python ../src/no_filter.py encode -c CBAAC -o 0

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/no_filter.py decode -c CBAAC -o 0

# %%
# %%bash
# python ../src/RDE.py
