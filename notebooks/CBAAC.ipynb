# %% [markdown]
# # Context-Based Adaptive Arithmetic Coding (CBAAC)

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %% [markdown]
# ### Exportar código fuente

# %% [markdown]
# ### Help

# %%
# !python ../src/CBAAC.py -h

# %%
# !python ../src/CBAAC.py encode -h

# %% [markdown]
# ### Encoding

# %%
# %%bash
# rm -f /tmp/encoded*
# python ../src/CBAAC.py encode --order 1

# %%
# !ls -lh /tmp/encoded.adpt_arith

# %% [markdown]
# ### Decoding

# %%
# !python ../src/CBAAC.py decode -h

# %%
# %%bash
# rm -f /tmp/decoded.png
# python ../src/CBAAC.py decode --order 1

# %% [markdown]
# ### Visualization

# %%
display(Image(filename="/tmp/original.png"))
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Performance metrics

# %%
# %%bash
# python ../src/RDE.py
