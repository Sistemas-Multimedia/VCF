# %% [markdown]
# ## Color DCT

# %%
from IPython.display import Image, display

# %%
# !wget http://www.hpca.ual.es/~vruiz/images/pajarillo_512x512.png -O /tmp/original.png

# %%
# !python ../src/color-DCT.py encode -h

# %%
# !python ../src/color-DCT.py encode -q 16

# %%
# !python ../src/color-DCT.py decode -h

# %%
# !python ../src/color-DCT.py decode -q 16

# %%
display(Image(filename="/tmp/pajarillo.png"))
display(Image(filename="/tmp/decoded.png"))

# %%
# !python ../src/YCrCb.py encode -q 16
# !python ../src/YCrCb.py decode -o /tmp/YCrCb.png -q 16
display(Image(filename="/tmp/YCrCb.png"))

# %% [markdown]
# ### Using (2D) VQ

# %%
# !python ../src/color-DCT.py encode -a VQ -n 32
# !python ../src/color-DCT.py decode -a VQ -n 32
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using LloydMax quantization

# %%
# !python ../src/YCoCg.py encode -a LloydMax -q 16
# !python ../src/YCoCg.py decode -a LloydMax -q 16
display(Image(filename="/tmp/decoded.png"))

# %%
# !python ../src/color-DCT.py encode -c LloydMax -q 16

# %%
#!python ../src/color-DCT.py -g decode -c LloydMax -q 16
#display(Image(filename="/tmp/decoded.png"))
