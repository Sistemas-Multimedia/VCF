# %% [markdown]
# ## Color DCT

# %%
from IPython.display import Image, display

# %%
#!pip install -r ../requirements.txt

# %% [markdown]
# ### Help

# %%
# !python ../src/color-DCT.py -h

# %%
# !python ../src/color-DCT.py encode -h

# %% [markdown]
# ### Encoding

# %%
# !wget http://www.hpca.ual.es/~vruiz/images/pajarillo_512x512.png -O /tmp/pajarillo.png

# %%
# !python ../src/color-DCT.py -g encode -i /tmp/pajarillo.png -q 16

# %% [markdown]
# ### Decoding

# %%
# !python ../src/color-DCT.py -g decode -q 16

# %%
display(Image(filename="/tmp/pajarillo.png"))
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Comparing with YCrCb

# %%
# !python ../src/YCrCb.py encode -i /tmp/pajarillo.png -q 16
# !python ../src/YCrCb.py decode -o /tmp/YCrCb.png -q 16
display(Image(filename="/tmp/YCrCb.png"))

# %% [markdown]
# ### Using (2D) VQ

# %%
# !python ../src/color-DCT.py encode -i /tmp/pajarillo.png -c VQ

# %%
# !python ../src/color-DCT.py decode -c VQ
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Try to use LloydMax quantization

# %%
# !python ../src/color-DCT.py encode -i /tmp/pajarillo.png -c LloydMax -q 16

# %%
#!python ../src/color-DCT.py -g decode -c LloydMax -q 16
#display(Image(filename="/tmp/decoded.png"))
