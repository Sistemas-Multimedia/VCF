# %% [markdown]
# # Block-based 2D MDCT (Modified Discrete Cosine Transform)

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %% [markdown]
# ### Basic Functionality - Encoding and Decoding Parameters
#
# The following examples show how to use MDCT in VCF for encoding and decoding images.

# %%
# !python ../src/2D-MDCT.py -h

# %% [markdown]
# ### Encoding Parameters

# %%
# !python ../src/2D-MDCT.py encode -h
# Out:
# usage: 2D-MDCT.py encode [-h] [-B BLOCK_SIZE_MDCT] [-t COLOR_TRANSFORM] [-p]
#                          [-x]
#
# options:
#   -h, --help            show this help message and exit
#   -B, --block_size_MDCT BLOCK_SIZE_MDCT
#                         Block size (default: 8)
#   -t, --color_transform COLOR_TRANSFORM
#                         Color transform (default: "YCoCg")
#   -p, --perceptual_quantization
#                         Use perceptual quantization (default: "False")
#   -x, --disable_subbands
#                         Disable the coefficients reordering in subbands
#                         (default: "False")

# %% [markdown]
# ### Basic example

# %%
# %%bash
# rm -f /tmp/encoded*
# python ../src/2D-MDCT.py encode
# rm -f /tmp/decoded.png
# python ../src/2D-MDCT.py decode
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using perceptual (low) quantization

# %%
# %%bash
# rm -f /tmp/encoded*
# python ../src/MDCT.py encode -p -q 4 -B 32
# rm -f /tmp/decoded.png
# python ../src/MDCT.py decode -p -q 4 -B 32
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using perceptual (high) quantization

# %%
# %%bash
# rm -f /tmp/encoded*
# python ../src/MDCT.py encode -p -q 8 -B 32
# rm -f /tmp/decoded.png
# python ../src/MDCT.py decode -p -q 8 -B 32
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))

# %% [markdown]
# ### Using the LloydMax quantizer

# %%
# %%bash
# rm -f /tmp/encoded*
# python ../src/MDCT.py encode -a LloydMax -m -2048 -n 2047
# rm -f /tmp/decoded.png
# python ../src/MDCT.py decode -a LloydMax -m -2048 -n 2047
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))
