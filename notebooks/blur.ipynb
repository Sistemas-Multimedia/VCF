# %% [markdown]
# ## Blurring images

# %%
from IPython.display import Image, display

# %%
#!pip install -r ../requirements.txt

# %%
# !wget http://www.hpca.ual.es/~vruiz/images/pajarillo_512x512.png -O /tmp/pajarillo.png

# %% [markdown]
# ### Help

# %%
# !python ../src/blur.py -h

# %% [markdown]
# ### Encoding
# Only for generating a TIFF copy of the input image (filtering is only performed when decoding).

# %%
# !python ../src/blur.py encode -h

# %%
# !python ../src/blur.py -g encode -i /tmp/pajarillo.png

# %% [markdown]
# ### Decoding (blurring)

# %%
# !python ../src/blur.py decode -h

# %%
# !python ../src/blur.py -g decode -f gaussian -s 7

# %%
display(Image(filename="/tmp/pajarillo.png"))
display(Image(filename="/tmp/decoded.png"))
