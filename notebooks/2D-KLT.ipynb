# %% [markdown]
# ## 2D - KLT (Karhunen-Loève Transform) image compression

# %%
from IPython.display import Image, display

# %%
# %run download_default_image.ipynb

# %%
# !python ../src/2D-KLT.py -h

# %%
# !python ../src/2D-KLT.py encode -h

# %%
# %%bash
# rm -f /tmp/encoded*
# python ../src/2D-KLT.py encode

# %%
# !ls -l /tmp/encoded*

# %%
# %%bash
# rm /tmp/decoded.png
# python ../src/2D-KLT.py decode
# python ../src/RDE.py

# %%
display(Image(filename="/tmp/decoded.png"))
